# %% [markdown]
# # Machine Learning Workflow
# Complete the steps below to complete the machine learning workflow for this classifier.

# %%
import nltk
nltk.download(['punkt', 'wordnet'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ziaeeamir\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ziaeeamir\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import confusion_matrix

# %%
url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'

def load_data():
    df = pd.read_csv('../dataset/corporate_messaging.csv', encoding='latin-1')
    df = df[(df["category:confidence"] == 1) & (df['category'] != 'Exclude')]
    X = df.text.values
    y = df.category.values
    return X, y

def tokenize(text):
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### Step 1: Load data and perform a train test split

# %%
# load data
X, y = load_data()

# perform train test split
X_train, X_test, y_train ,  y_test = train_test_split(X,y)

# %%
print(X_train.shape, y_train.shape , X_test.shape, y_test.shape)
# Out:
# (1802,) (1802,) (601,) (601,)

# %% [markdown]
# ### Step 2: Train classifier
# * Fit and transform the training data with `CountVectorizer`. Hint: You can include your tokenize function in the `tokenizer` keyword argument!
# * Fit and transform these word counts with `TfidfTransformer`.
# * Fit a classifier to these tfidf values.

# %%
# Instantiate transformers and classifier
vect = CountVectorizer(tokenizer=tokenize)
tfidf = TfidfTransformer()
clf =  RandomForestClassifier()

# Fit and/or transform each to the data

X_train_count = vect.fit_transform(X_train)
X_train_tfidf = tfidf.fit_transform(X_train_count)
print(X_train_tfidf.toarray().shape,y_train.shape)
clf.fit(X_train_tfidf, y_train)
# Out:
# (1802, 5607) (1802,)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ### Convert sparse matrix to numpy array to view

# %%
X_train_count.toarray()[0].shape, X_train_count.toarray()[0]
# Out:
# ((5607,), array([0, 1, 0, ..., 0, 0, 0], dtype=int64))

# %%
vect.vocabulary_
# Out:
# {'what': 5374,
#  'is': 2834,
#  'the': 4936,
#  'bond': 856,
#  'between': 782,
#  'duct': 1736,
#  'tape': 4889,
#  'and': 540,
#  '#': 1,
#  'healthcare': 2501,
#  '?': 341,
#  'see': 4478,
#  '@': 342,
#  'vrulon': 5268,
#  'ha': 2448,
#  'to': 4989,
#  'say': 4431,
#  'urlplaceholder': 5175,
#  'avieweiss': 671,
#  'we`ve': 5328,
#  'voluntarily': 5257,
#  'recalled': 4167,
#  'limited': 3098,
#  'amount': 530,
#  'of': 3648,
#  'nesquik': 3527,
#  'chocolate': 1124,
#  'powder': 3941,
#  'sold': 4631,
#  'only': 3674,
#  'in': 2693,
#  'u': 5109,
#  '.': 60,
#  'for': 2183,
#  'info': 2731,
#  'danone': 1505,
#  'water': 5318,
#  'toured': 5018,
#  'seaside': 4462,
#  'town': 5024,
#  'france': 2217,
#  '3rd': 236,
#  'yr': 5519,
#  'this': 4962,
#  'summer': 4818,
#  '&': 4,
#  'amp': 531,
#  '1st': 148,
#  'time': 4982,
#  'brazil': 892,
#  'spain': 4658,
#  ',': 47,
#  'promote': 4049,
#  'healthy': 2506,
#  'hydration': 2640,
#  'barclays': 708,
#  'wealth': 5330,
#  'tell': 4917,
#  'client': 1193,
#  'add': 411,
#  'developed': 1607,
#  'market': 3238,
#  'stock': 4755,
#  'how': 2609,
#  'easy': 1764,
#  'it': 2844,
#  'cook': 1375,
#  'fire-roasted': 2136,
#  'corn': 1393,
#  'salad': 4405,
#  'w/': 5273,
#  'grilled': 2403,
#  'chicken': 1109,
#  'from': 2236,
#  'celebrity': 1036,
#  'chefartsmith': 1099,
#  ':': 338,
#  'citigroup': 1154,
#  'above': 364,
#  'fed': 2080,
#  'standard': 4714,
#  'stress': 4775,
#  'test': 4922,
#  'brk': 917,
#  'corporate': 1397,
#  'responsibility': 4290,
#  'at': 643,
#  'merck': 3311,
#  '\x89ûò': 5573,
#  'investment': 2805,
#  'united': 5153,
#  'negro': 3518,
#  'college': 1245,
#  'fund/merck': 2259,
#  'science': 4445,
#  'initiative': 2749,
#  '$': 2,
#  '37.5': 231,
#  'million': 3364,
#  'since': 4570,
#  '1996': 146,
#  'bewell': 784,
#  'rt': 4371,
#  'wsj': 5469,
#  'report': 4265,
#  'why': 5389,
#  'rich': 4324,
#  'give': 2337,
#  'charity': 1085,
#  '-': 48,
#  'notion': 3600,
#  'legacy': 3050,
#  'behind': 751,
#  'more': 3413,
#  'today': 4991,
#  "'s": 30,
#  'philanthropic': 3852,
#  'g': 2271,
#  '...': 62,
#  'tech': 4907,
#  'transforming': 5051,
#  'our': 3706,
#  'daily': 1495,
#  'life': 3083,
#  'city': 1172,
#  'that': 4934,
#  'balance': 696,
#  'human': 2625,
#  'ingenuity': 2738,
#  'power': 3943,
#  'will': 5395,
#  'be': 733,
#  'most': 3425,
#  'competitive': 1291,
#  'ncs2014': 3501,
#  'citiforcities': 1152,
#  'activia': 403,
#  'jamie': 2870,
#  'lee': 3046,
#  'curtis': 1474,
#  'team': 4903,
#  'up': 5163,
#  'educate': 1785,
#  'american': 526,
#  'on': 3665,
#  'impact': 2680,
#  'digestive': 1634,
#  'health': 2497,
#  'mind': 3369,
#  'body': 846,
#  'enrobing': 1878,
#  'food': 2170,
#  'can': 984,
#  'make': 3195,
#  'them': 4944,
#  'last': 3011,
#  'longer': 3136,
#  'particularly': 3779,
#  'those': 4964,
#  'prone': 4051,
#  'drying': 1730,
#  'out': 3709,
#  'chocolatecoveredfacts': 1126,
#  'asco': 618,
#  'thank': 4931,
#  'you': 5511,
#  'a': 348,
#  'great': 2389,
#  'meeting': 3290,
#  '!': 0,
#  'we': 5327,
#  "'ve": 35,
#  'especially': 1917,
#  'enjoyed': 1872,
#  'following': 2167,
#  'conversation': 1371,
#  'social': 4620,
#  'medium': 3287,
#  'asco14': 621,
#  'april': 596,
#  '30': 220,
#  'institute': 2767,
#  'international': 2786,
#  'took': 5004,
#  'part': 3774,
#  '2nd': 205,
#  'global': 2348,
#  'summit': 4819,
#  'effect': 1791,
#  'yogurt': 5505,
#  'yini2014': 5500,
#  'management': 3210,
#  'sponsor': 4683,
#  'iod': 2813,
#  'seminar': 4497,
#  'director': 1645,
#  'role': 4349,
#  'managing': 3212,
#  'risk': 4337,
#  'berthold': 774,
#  'koletzko': 2970,
#  'child': 1111,
#  'hospital': 2599,
#  'uni': 5146,
#  'munich': 3462,
#  'now': 3606,
#  'talking': 4882,
#  'about': 363,
#  'infant': 2726,
#  'feeding': 2086,
#  'practice': 3950,
#  'development': 1609,
#  'obesity': 3638,
#  'nins2013': 3575,
#  'wsjwealthreport': 5471,
#  'biggest': 797,
#  'richest': 4326,
#  'party': 3785,
#  'ever': 1949,
#  'world': 5448,
#  'struggling': 4788,
#  'emerge': 1821,
#  'recession': 4175,
#  'creating': 1439,
#  'shared': 4529,
#  'value': 5200,
#  'valid': 5199,
#  'developing': 1608,
#  'peter': 3838,
#  'brabeck-letmathe': 884,
#  'nestle': 3528,
#  'csv2011': 1461,
#  'touchms': 5015,
#  'asked': 627,
#  'fla': 2147,
#  'map': 3224,
#  'cocoa': 1229,
#  'supply': 4827,
#  'chain': 1067,
#  'published': 4084,
#  'action': 398,
#  'plan': 3885,
#  'work': 5433,
#  'their': 4942,
#  'recos': 4194,
#  'awarded': 675,
#  'new': 3547,
#  'ceo': 1048,
#  'michael': 3334,
#  'corbat': 1390,
#  'total': 5012,
#  '12.4': 106,
#  'year': 5492,
#  'york': 5509,
#  'n': 3475,
#  'first': 2140,
#  'csv': 1460,
#  'prize': 4009,
#  'wa': 5288,
#  'ide': 2657,
#  'cambodia': 974,
#  '2010': 168,
#  'forum': 2200,
#  'london': 3132,
#  'nestlecsv': 3532,
#  'who': 5384,
#  'cooked': 1376,
#  'alongside': 509,
#  'parent': 3768,
#  'ate': 644,
#  'almost': 506,
#  '76': 307,
#  '%': 3,
#  'full': 2251,
#  'healthykids': 2509,
#  'patchworkcactus': 3791,
#  'formula': 2196,
#  'nan': 3482,
#  'h.a': 2443,
#  '1': 71,
#  'gold': 2366,
#  'safe': 4395,
#  'read': 4148,
#  'here': 2541,
#  'capital': 996,
#  'xv': 5488,
#  'trust': 5079,
#  'preferred': 3960,
#  'security': 4476,
#  'ex-dividend': 1965,
#  'reminder': 4250,
#  '3/12/13': 218,
#  'working': 5441,
#  'together': 4996,
#  'healthier': 2503,
#  'caroline': 1010,
#  'roan': 4345,
#  'purpose': 4092,
#  'pfizer\x89ûªs': 3844,
#  'business': 945,
#  'study': 4792,
#  'also': 513,
#  'suggested': 4811,
#  'helping': 2535,
#  'prepare': 3966,
#  'meal': 3272,
#  'increased': 2705,
#  'positive': 3930,
#  'emotion': 1829,
#  'pride': 3999,
#  'liverusa': 3120,
#  'proud': 4065,
#  'event': 1947,
#  'nextbillion': 3555,
#  'featuring': 2079,
#  'pfizer': 3841,
#  'bop': 866,
#  'effort': 1796,
#  'africa': 454,
#  'malaria': 3199,
#  'mhealth': 3329,
#  'socentchat': 4618,
#  'bopbiz': 867,
#  'exclusive': 1976,
#  'tpg': 5026,
#  'madison': 3181,
#  'dearborn': 1541,
#  'final': 2118,
#  'bidder': 791,
#  'nfp': 3557,
#  'source': 4651,
#  'reduced': 4209,
#  'number': 3612,
#  'workplace': 5445,
#  'accident': 378,
#  'requiring': 4276,
#  'sick': 4553,
#  'leave': 3041,
#  'by': 957,
#  '5': 256,
#  '2004': 161,
#  'people': 3817,
#  'within': 5411,
#  'next': 3554,
#  'five': 2144,
#  'over': 3725,
#  'age': 462,
#  '65': 290,
#  'outnumber': 3719,
#  'under': 5127,
#  'newstakes': 3552,
#  'mansur': 3218,
#  'gidfar': 2331,
#  'there': 4951,
#  'something': 4642,
#  'absolutely': 365,
#  'insane': 2757,
#  'happening': 2465,
#  'house': 2606,
#  'right': 4329,
#  'have': 2481,
#  'big': 793,
#  'moment': 3402,
#  'arrived': 612,
#  'ftcitiawards': 2248,
#  'winner': 5403,
#  'announced': 556,
#  'tonight': 5001,
#  '9pm': 336,
#  'est': 1920,
#  'learn': 3037,
#  'progressmakers': 4038,
#  'barbara': 707,
#  'roll': 4350,
#  'simple': 4568,
#  'strategy': 4766,
#  'focusing': 2162,
#  'energy': 1858,
#  'density': 1584,
#  'may': 3261,
#  'help': 2532,
#  'prevent': 3987,
#  'weight': 5353,
#  'regain': 4219,
#  'after': 458,
#  'loss': 3148,
#  '45': 249,
#  'minute': 3377,
#  'follow': 2164,
#  'second': 4465,
#  'investor': 2806,
#  '2011': 170,
#  'nestleir': 3533,
#  'analysis': 535,
#  's': 4389,
#  'p': 3741,
#  'paper': 3764,
#  'trail': 5044,
#  'lead': 3030,
#  'nowhere': 3608,
#  'government': 2376,
#  'case': 1013,
#  'partnership': 3784,
#  'disease': 1661,
#  'foundation': 2205,
#  'open': 3679,
#  'avenue': 669,
#  'drug': 1725,
#  'discovery': 1654,
#  'julie': 2921,
#  'howard': 2610,
#  'pleasing': 3900,
#  'president': 3980,
#  'obama': 3636,
#  'engaging': 1866,
#  'issue': 2842,
#  'get': 2317,
#  'interesting': 2782,
#  'when': 5377,
#  'fail': 2037,
#  'because': 737,
#  'that\x89ûªs': 4935,
#  'surpass': 4837,
#  'ourselves': 3708,
#  'pfizer_news': 3842,
#  'tedactive': 4912,
#  'activehealth': 402,
#  'better': 781,
#  'buy': 950,
#  'or': 3695,
#  'jpmorgan': 2915,
#  'chase': 1089,
#  'tony': 5002,
#  'coyle': 1425,
#  'cti': 1465,
#  'alliance4lupus': 502,
#  'discus': 1657,
#  'we\x89ûªre': 5369,
#  'co-funding': 1221,
#  'research': 4278,
#  'develop': 1606,
#  'therapy': 4949,
#  'patient': 3800,
#  'w/lupus': 5282,
#  'p4c2013': 3744,
#  'elaonik': 1804,
#  "'re": 28,
#  'should': 4545,
#  'take': 4875,
#  'care': 1003,
#  'celebrate': 1031,
#  'each': 1753,
#  'day': 1534,
#  'nestlì©': 3535,
#  'strengthens': 4774,
#  'scientific': 4447,
#  'commitment': 1260,
#  'china': 1120,
#  'with': 5409,
#  'laboratory': 2989,
#  'froman': 2237,
#  'said': 4403,
#  'front-runner': 2240,
#  'trade': 5035,
#  'representative': 4267,
#  'barack': 706,
#  'close': 1200,
#  'ch': 1066,
#  'battling': 720,
#  'your': 5514,
#  'robert': 4347,
#  'l.': 2982,
#  'thompson': 4963,
#  'don\x89ûªt': 1699,
#  'resource': 4286,
#  'do': 1678,
#  'alone': 507,
#  'foreign': 2189,
#  'aid': 479,
#  'strategic': 4764,
#  'partner': 3780,
#  'planetworkshops': 3887,
#  'edition': 1782,
#  'co-construction': 1218,
#  'globalc2012': 2349,
#  'community': 1276,
#  'impacted': 2681,
#  'crime': 1447,
#  'theccjamaica': 4938,
#  'fish': 2142,
#  'farm': 2058,
#  'paraguay': 3766,
#  'citi': 1143,
#  'reward': 4317,
#  'top': 5006,
#  'microentrepreneurs': 3343,
#  'strengthening': 4773,
#  'well-being': 5358,
#  'citimea': 1155,
#  'win': 5398,
#  'four': 2209,
#  'award': 673,
#  'singapore': 4572,
#  'contact': 1354,
#  'centre': 1045,
#  'association': 639,
#  'hspecialsurgery\x89ûªs': 2615,
#  'hsscircus': 2616,
#  'they': 4955,
#  'pediatric': 3814,
#  'support': 4828,
#  'hospitalization': 2600,
#  'er': 1909,
#  'visit': 5239,
#  'drive': 1722,
#  'declining': 1557,
#  'cost': 1403,
#  'assoc': 637,
#  'improved': 2690,
#  'medication': 3285,
#  'adherence': 418,
#  'valueofmeds': 5201,
#  'apixaban': 576,
#  'statistically': 4735,
#  'superior': 4826,
#  'enoxaparin': 1875,
#  'prevention': 3992,
#  'venous': 5214,
#  'thromboembolism': 4970,
#  'clive': 1198,
#  'tasker': 4893,
#  'bank': 702,
#  'small': 4603,
#  'holder': 2577,
#  'lending': 3055,
#  'must': 3465,
#  'profit': 4031,
#  'center': 1042,
#  'not': 3597,
#  'csr': 1459,
#  'medical': 3282,
#  'nutrition': 3619,
#  '35': 228,
#  'share': 4528,
#  'acquisition': 393,
#  'nutrimed': 3618,
#  'strengthen': 4771,
#  'manufacturing': 3222,
#  'capacity': 994,
#  'wish': 5407,
#  'tree': 5065,
#  'possible': 3933,
#  'via': 5222,
#  'edible': 1780,
#  'playground': 3896,
#  'rethink': 4298,
#  'branch': 887,
#  'but': 948,
#  'ì¢\x89ââèïyou': 5605,
#  'charge': 1083,
#  'own': 3736,
#  'bodyì¢\x89ââ\x89ã¢': 849,
#  'kid': 2955,
#  'programme': 4036,
#  'japan': 2872,
#  'adopt': 426,
#  'diet': 1627,
#  'wfd2013': 5372,
#  'an': 533,
#  'ambitious': 524,
#  'younger': 5513,
#  'breed': 900,
#  'wealthy': 5333,
#  'philanthropist': 3853,
#  'known': 2969,
#  'go': 2359,
#  'giver': 2340,
#  'are': 603,
#  'emerging': 1823,
#  'despite': 1599,
#  'chairman': 1069,
#  "'major": 23,
#  "'": 5,
#  'done': 1696,
#  'shedding': 4534,
#  'asset': 635,
#  'david': 1531,
#  'henry': 2538,
#  '(': 38,
#  'reuters': 4304,
#  'european': 1937,
#  'customer': 1476,
#  'service': 4514,
#  'downside': 1709,
#  'control-freak': 1368,
#  'philanthropy': 3854,
#  'vega': 5210,
#  'tycoon': 5106,
#  '\x89û÷so': 5583,
#  'i': 2643,
#  'lost': 3149,
#  '25': 190,
#  'billion\x89ûª': 807,
#  'sheldon': 4536,
#  'adelson': 415,
#  'know': 2967,
#  'thing': 4957,
#  'two': 5104,
#  'poverty': 3940,
#  'havi': 2482,
#  'fellow': 2091,
#  'randy': 4126,
#  'kaja': 2933,
#  'iavi': 2647,
#  'coaching': 1222,
#  'iavi-partner': 2648,
#  'scientist': 4450,
#  'really': 4160,
#  'safest': 4400,
#  'stricter': 4776,
#  'securitization': 4475,
#  'rule': 4375,
#  'hurt': 2635,
#  'lobbying': 3128,
#  'against': 460,
#  'internati': 2785,
#  'produce': 4017,
#  'guide': 2429,
#  'resident': 4281,
#  'bronx': 924,
#  'nyc': 3627,
#  'consumer': 1349,
#  'concern': 1305,
#  'continuing': 1361,
#  'focus': 2160,
#  'moved': 3434,
#  'ecology': 1772,
#  'being': 753,
#  'fringe': 2234,
#  'phenomenon': 3851,
#  'into': 2791,
#  'mainstream': 3191,
#  'euromonitor': 1934,
#  'green': 2395,
#  'eb__live': 1768,
#  'join': 2894,
#  'discover': 1652,
#  'way': 5323,
#  'approach': 588,
#  'benefit': 766,
#  'register': 4224,
#  'eblive2013': 1769,
#  'latest': 3015,
#  'show': 4547,
#  'gen': 2303,
#  'z': 5523,
#  'flexible': 2155,
#  'access': 377,
#  'career': 1004,
#  'socially': 4624,
#  'aware': 677,
#  'saba': 4392,
#  'hire': 2565,
#  'trader': 5038,
#  'rbc': 4140,
#  'kazarian': 2939,
#  'gabriel': 2274,
#  'led': 3044,
#  'cred': 1443,
#  'getold': 2320,
#  'toddler': 4995,
#  'morphs': 3421,
#  'elderly': 1805,
#  'man': 3207,
#  '40': 243,
#  'letsgetold': 3063,
#  'embrace': 1818,
#  'riskier': 4338,
#  'block': 834,
#  'proudly': 4066,
#  'sponsoring': 4685,
#  'tedxrc2': 4913,
#  'geneva': 2312,
#  'just': 2926,
#  'few': 2099,
#  'find': 2128,
#  'sharing': 4532,
#  'idea': 2658,
#  '27': 196,
#  'nov': 3602,
#  'p.bulcke': 3743,
#  'malnutrition': 3205,
#  'seriously': 4511,
#  'impairs': 2682,
#  'develpmnt': 1611,
#  'negatively': 3515,
#  'affect': 446,
#  'labour': 2990,
#  'productivity': 4023,
#  'economy': 1776,
#  'csvforum': 1462,
#  'jamaica': 2868,
#  'belize': 756,
#  'suriname': 4836,
#  'earn': 1758,
#  'microentrepreneurship': 3344,
#  'supporting': 4831,
#  'ambition': 523,
#  'achievement': 390,
#  'goldman': 2368,
#  'warn': 5307,
#  'shareholder': 4531,
#  'cybersecurity': 1481,
#  'marielis311': 3233,
#  'marielis': 3232,
#  'enthusiastic': 1887,
#  'colleague': 1243,
#  'like': 3093,
#  ')': 39,
#  'well': 5357,
#  'gmitcalfe': 2357,
#  'citivolunteers': 1161,
#  'start': 4723,
#  'spitalfields': 4680,
#  'spitz_cityfarm': 4681,
#  'healthybytes': 2508,
#  'much': 3454,
#  'drink': 1718,
#  'tip': 4985,
#  'staying': 4739,
#  'hydrated': 2639,
#  'office': 3653,
#  'sticking': 4752,
#  'thumb': 4975,
#  'ride': 4328,
#  'long': 3134,
#  'gone': 2369,
#  'blablacaruk': 821,
#  'encourages': 1853,
#  'digital': 1636,
#  'hitchhiking': 2573,
#  'eal_awards': 1754,
#  'keep': 2940,
#  'good': 2370,
#  'ed': 1779,
#  'employment4youth': 1840,
#  'eirum': 1801,
#  'chaudhri': 1090,
#  'honoring': 2591,
#  'healthworkers': 2505,
#  'therealawards': 4952,
#  'whwweek': 5388,
#  'bn': 842,
#  'early': 1756,
#  'division': 1675,
#  'hit': 2572,
#  'further': 2266,
#  'steep': 4742,
#  'decline': 1556,
#  '-6.9': 51,
#  'sale': 4406,
#  'q4': 4104,
#  'result': 4294,
#  'false': 2050,
#  'safety': 4401,
#  'alert': 487,
#  'fy2013': 2270,
#  'designing': 1598,
#  'app': 577,
#  'hack': 2451,
#  'weekend': 5346,
#  'socialmediaweek': 4626,
#  'semilla': 4496,
#  'project': 4039,
#  'created': 1437,
#  'provide': 4068,
#  'training': 5047,
#  'woman': 5420,
#  'need': 3509,
#  'job': 2889,
#  'danoneecosysteme': 1512,
#  'multiple': 3459,
#  'collaboration': 1240,
#  'advance': 430,
#  'cancer': 987,
#  'program': 4035,
#  '-r.': 59,
#  'perlmutter': 3827,
#  'mrk': 3446,
#  'mammogram': 3206,
#  'myth': 3473,
#  'fact': 2033,
#  'gethealthystayhealthy': 2319,
#  'slow': 4600,
#  'growth': 2415,
#  'emboldens': 1816,
#  'stay': 4738,
#  'course': 1418,
#  'paul': 3804,
#  'bulcke': 940,
#  'perform': 3824,
#  'school': 4442,
#  'productive': 4022,
#  'adults..it': 429,
#  'virtuous': 5236,
#  'circle': 1140,
#  'wef2014': 5349,
#  'commits': 1261,
#  '250k': 191,
#  'family': 2052,
#  'devastated': 1605,
#  'typhoon': 5108,
#  'haiyan': 2456,
#  'redcross': 4201,
#  'gary': 2288,
#  'pelletier': 3815,
#  'helpful': 2534,
#  'answer': 562,
#  'participates': 3777,
#  'hall': 2458,
#  'latino': 3018,
#  'usa': 5178,
#  'addressing': 413,
#  '4': 238,
#  'attitude': 654,
#  'financial': 2123,
#  'planning': 3889,
#  'which': 5380,
#  'doe': 1682,
#  'workforce': 5440,
#  'i_am_funny_one': 2644,
#  'detail': 1602,
#  'all': 494,
#  'migraine': 3351,
#  'treatment': 5064,
#  'equal': 1902,
#  'campaign': 981,
#  'relief': 4240,
#  'campaignagainstmigraine': 982,
#  'ernest': 1912,
#  'goodpasture\x89ûªs': 2372,
#  'reduction': 4211,
#  'disappearance': 1647,
#  'some': 4640,
#  'world\x89ûªs': 5458,
#  'harmful': 2474,
#  '2014': 175,
#  'q1': 4101,
#  'call': 969,
#  'started': 4725,
#  'live': 3113,
#  'honduras': 2585,
#  'leed': 3047,
#  'certification': 1053,
#  'citisustainability': 1159,
#  'getgreen': 2318,
#  'socialmedia': 4625,
#  'maximize': 3260,
#  'return': 4300,
#  'yec': 5496,
#  'giving': 2341,
#  '1.7': 82,
#  'billion': 805,
#  'product': 4020,
#  'cash': 1014,
#  'donation': 1694,
#  'wall': 5301,
#  'street': 4768,
#  'wrongdoer': 5467,
#  'wo': 5416,
#  "n't": 3476,
#  'admit': 423,
#  'wrongdoing': 5468,
#  'securiti': 4474,
#  'pursuing': 4093,
#  'worklifebalance': 5443,
#  'pivotal': 3881,
#  'her': 2540,
#  'son': 4646,
#  'christine': 1134,
#  'lam': 2998,
#  'change': 1077,
#  'womensday': 5424,
#  'begin': 744,
#  'fresh': 2230,
#  'round': 4362,
#  'cut': 1478,
#  'r': 4114,
#  'd': 1490,
#  'mikael': 3353,
#  'dolsten': 1688,
#  'speak': 4662,
#  'forbeshealth': 2185,
#  '2013': 172,
#  'panel': 3763,
#  'drugresearch': 1727,
#  'tracy': 5034,
#  'sienko': 4556,
#  'ghf': 2324,
#  'underserved': 5132,
#  'population': 3920,
#  'tanzania': 4887,
#  '3,800': 211,
#  'taiwan': 4874,
#  'back': 687,
#  'spending': 4676,
#  'orphan': 3702,
#  'underprivileged': 5130,
#  'congress': 1326,
#  'enact': 1849,
#  'uniform': 5148,
#  'national': 3491,
#  'solution': 4636,
#  'secure': 4470,
#  'u.s.': 5111,
#  'pharmaceutical': 3847,
#  'distribution': 1668,
#  'collaborating': 1239,
#  'latinastylemag': 3017,
#  'online': 3673,
#  'tool': 5005,
#  'hispanic': 2568,
#  'did': 1624,
#  'lungcancer': 3167,
#  'metastatic': 3320,
#  'brain': 886,
#  'tumor': 5088,
#  'ecc2013': 1771,
#  'uk': 5116,
#  'real': 4152,
#  'prescription': 3972,
#  'counterfeit': 1413,
#  'med': 3278,
#  'ad': 408,
#  'youtube': 5518,
#  'select': 4488,
#  'vote': 5264,
#  'realdanger': 4155,
#  'maturist': 3257,
#  'concerned': 1306,
#  'pension': 3816,
#  'saving': 4429,
#  'shaped': 4527,
#  'today\x89ûªs': 4993,
#  'linkedin': 3104,
#  'connect': 1329,
#  'profwomen': 4033,
#  'network': 3539,
#  'topped': 5010,
#  'member': 3298,
#  'lindadescano': 3100,
#  '3/5': 219,
#  'rsvp': 4370,
#  'sachin': 4394,
#  'jain': 2867,
#  'talk': 4880,
#  'modern': 3397,
#  'medicine': 3286,
#  'requires': 4275,
#  'across': 395,
#  'boundary': 882,
#  'gardening': 2285,
#  'reduce': 4208,
#  'enjoy': 1871,
#  'outdoors': 3716,
#  'if': 2664,
#  'safely': 4398,
#  'check': 1092,
#  'these': 4953,
#  'sheila': 4535,
#  'bair': 693,
#  'end': 1855,
#  'too': 5003,
#  'jay': 2874,
#  'motley': 3431,
#  'fool': 2179,
#  'blog': 835,
#  '--': 49,
#  'innovation': 2755,
#  'technology': 4911,
#  'transaction': 5048,
#  'banking': 704,
#  'push': 4094,
#  'ignore': 2667,
#  'rival': 4339,
#  'setting': 4518,
#  'bonus': 859,
#  'federal': 2082,
#  'reserve': 4280,
#  'cmo': 1213,
#  'bigdata': 795,
#  'healthinnovation': 2504,
#  'morning': 3417,
#  '0830cet': 70,
#  'hpv': 2611,
#  'cause': 1022,
#  'cervicalcancer': 1054,
#  'during': 1741,
#  'cervicalhealthmonth': 1055,
#  'md': 3269,
#  ...}

# %% [markdown]
# ### Step 3: Predict on test data
# * Transform (no fitting) the test data with the same CountVectorizer and TfidfTransformer
# * Predict labels on these tfidf values.

# %%
# Transform test data
X_test_count = vect.transform(X_test)
X_test_tfidf = tfidf.transform(X_test_count)

# Predict test labels
y_pred = clf.predict(X_test_tfidf)

# %% [markdown]
# ### Step 4: Display results
# Display a confusion matrix and accuracy score based on the model's predictions.

# %%
labels = np.unique(y_test)
confusion_mat = confusion_matrix(y_test, y_pred,labels=labels)
accuracy = (y_test==y_pred).mean()

print("Labels:", labels)
print("Confusion Matrix:\n", confusion_mat)
print("Accuracy:", accuracy)
# Out:
# Labels: ['Action' 'Dialogue' 'Information']
# Confusion Matrix:
#  [[ 84   1  31]
#  [  2  26   2]
#  [ 18   2 435]]
# Accuracy: 0.9068219633943427

# %% [markdown]
# # Final Step: Refactor
# Organize these steps into the following functions.

# %%
def display_results(y_test, y_pred):
    # insert step 4 here 
    labels = np.unique(y_test)
    confusion_mat = confusion_matrix(y_test, y_pred,labels=labels)
    accuracy = (y_test==y_pred).mean()

    print("Labels:", labels)
    print("Confusion Matrix:\n", confusion_mat)
    print("Accuracy:", accuracy)



def main():
    # load data
    X, y = load_data()

    # perform train test split
    X_train, X_test, y_train ,  y_test = train_test_split(X,y)
    
    # Instantiate transformers and classifier
    vect = CountVectorizer(tokenizer=tokenize)
    tfidf = TfidfTransformer()
    clf =  RandomForestClassifier()

    # Fit and/or transform each to the data

    X_train_count = vect.fit_transform(X_train)
    X_train_tfidf = tfidf.fit_transform(X_train_count)
    clf.fit(X_train_tfidf, y_train)
    
    # Transform test data
    X_test_count = vect.transform(X_test)
    X_test_tfidf = tfidf.transform(X_test_count)

    # Predict test labels
    y_pred = clf.predict(X_test_tfidf)
    
    display_results(y_test, y_pred)

# %%
# run program
main()
# Out:
# Labels: ['Action' 'Dialogue' 'Information']
# Confusion Matrix:
#  [[ 78   0  39]
#  [  3  20   7]
#  [ 10   0 444]]
# Accuracy: 0.9018302828618968
